# %%
import pandas as pd
import geopandas as gp

localidades = pd.read_csv("localidades.csv")

# %%
poligono = gp.read_file("provincia/provincia.shp")

# %%
poligono[poligono.nam.str.contains("Tierra")]
# Out:
#     entidad     objeto                                                fna  \
# 16        0  Provincia  Provincia de Tierra del Fuego, Antártida e Isl...
#
#           gna                                                nam in1  \
# 16  Provincia  Tierra del Fuego, Antártida e Islas del Atlánt...  94
#
#           fdc  sag                                           geometry
# 16  Geografía  IGN  (POLYGON Z ((-24.99999999999994 -75.8768696479...

# %%
poligono.plot(edgecolor='y', facecolor='none', figsize=(15, 10))
